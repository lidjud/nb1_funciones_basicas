# %% [markdown]
# <a href="https://colab.research.google.com/github/lidjud/nb1_funciones_basicas/blob/main/NB1_Funciones_b%C3%A1sicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Hello world! (10 × 3 in).png](data:image/png;base64,...)

# %% [markdown]
# # Función print()

# %% [markdown]
# Iniciaremos con la declaración de una función muy sencilla, la función ```print()``` la cual nos permite imprimir un mensaje que se coloca entre los paréntesis.
#
# Además de los parentésis, agregamos comilla doble o sencilla para indicar que lo que está entre comillas, no es código.
#
# En la siguiente línea de código, escribe el mensaje Hello world! entre las comillas y ejecútala.

# %%
print()

# %% [markdown]
# En la siguiente línea de código, imprime distintos mensajes, ¿qué sucede si quitas algunas de las comillas?

# %% [markdown]
# ## strings

# %% [markdown]
# El texto que mandas a imprimir, en programación, se conocen como **"strings"**. Las comillas nos indican el inicio y el final de una cadena de caracteres.

# %% [markdown]
# # **Challenge 1: Printing**

# %% [markdown]
# ## Uso de la `"\n"`

# %% [markdown]
# Un método para tener el menor número de líneas de código es la diagonal invertida ```"\n"```.

# %%
print("Hello word!\nHello word\nHello word")

# %% [markdown]
# Puedes concatenar cadenas utilizando el signo ```+```.

# %%
print("Hello" + "Ana")

# %% [markdown]
# # **Challenge 2: Debugging practice 🐞**

# %% [markdown]
# # Función input()

# %% [markdown]
# Esta función permite que el usuario ingrese algún dato.
# Es semejante a la función anterior, la cadena de caracteres debe ir entre comillas dobles o sencillas.

# %%
input("¿Cual es tu nombre?")

# %% [markdown]
# Observa lo que sucede cuando anidas las funciones ```input()``` y ```print()```.

# %%
print("Hola " + input("¿Cuál es tu nombre?"))

# %% [markdown]
# [Thonny](https://thonny.org/) es un programa muy interesante para empezar a aprender Python ya que engloba estas tres herramientas: intérprete, editor y depurador.

# %% [markdown]
# ## Comentarios en el código

# %% [markdown]
# Puedes escribir comentarios en tu código y que el ordenador lo ignore por completo. Para ello, utiliza el símbolo **"#"**.
#
# Esto te permite escribir notas y documentar tu código sin afectar el programa.
#
# También puedes hacer comentarios que se extienden por múltiples líneas encerrando el texto entre ```'''```.
#
# Ejecuta la siguiente línea de código, ¿obtienes alguna salida?

# %%
#Este es un comentario

# %% [markdown]
# Escribir comentarios en nuestro código, nos ayudar a recordar lo que está pasando en él.

# %%
# input() recibe una entrada del usuario
# Entonces print() imprime la palabra  Hola y la entrada del usuario
# También puedes seleccionar todos las filas y utilizar "Ctrl+z" para comentar las líneas seleccionadas.

print("Hola " + input("¿Cuál es tu nombre?") + "!")

# %% [markdown]
# # **Challenge 3: input() function**

# %% [markdown]
# # Variables en python

# %% [markdown]
# En Python, nombrarás a la variable y usarás el signo ```=``` para asignarle un valor. Por ejemplo:
#
# >```
# mensaje = "Hola mundo!"
# n = 10
# pi = 3.14159265
# ```

# %% [markdown]
# Restricciones:
# * Algunas palabras son reservadas por Python y no se pueden utilizar como nombres de variables.
#
#   Palabras reservadas:
#   > ```
#   False class finally is return
#   None continue for lambda try
#   True def from nonlocal while
#   and del global not with
#   as elif if or yield
#   assert else import pass
#   break except in raise
#   ```
# * Una variable no puede iniciar con dígitos, por ejemplo, ```20gatos``` no es un nombre válido.

# %% [markdown]
# Algunas recomendaciones para elegir nombres de variables:
# * Utiliza nombres que permitan identificar para qué es utilizada:
#
#   >```
#   pi = 3.14159265
#   mensaje = "Hola mundo!"
#   segundos_por_dia = 86400
#   ```
# * Puedes usar nombres cortos para las variables (```i``` y ```j```) cuando solo las usarás durante una pequeña sección de código.
# * Para evitar confusiones, es común usar únicamente letras minúsculas en el nombre de las variables.
# * Para variables con múltiples palabras, utiliza ```_``` para separarlas (```segundos_por_dia```).

# %% [markdown]
# A continuación, asignaremos una variable al nombre del usuario.

# %%
name = input("¿Cual es tu nombre?")

# %% [markdown]
# Ahora puedes hacer referencia al nombre adjuntado a name.

# %%
print(name)

# %% [markdown]
# El valor de la variable ```name``` puede cambiar...

# %%
print(name)
name = "Laura"
print(name)
name = "Eduardo"
print(name)

# %%
# Referente al challenge 3
print(len(input("¿Cuál es tu nombre?")))

# %%
nombre = input("¿Cuál es tu nombre?")
longitud = len(nombre)
print(longitud)

# %% [markdown]
# # **Challenge 4: Variables**
